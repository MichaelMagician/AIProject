# %% [markdown]
# # Movie sentiment prediction using naive bayes

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import re

# %% [markdown]
# ### read data

# %%
train_data = pd.read_csv('./data/movie_sentiment_nb2/labeledTrainData.csv', sep='\t')
test_data = pd.read_csv('./data/movie_sentiment_nb2/testData.csv', sep='\t')
print(train_data.head(2))
print(test_data.head(2))
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
#          id                                             review
# 0  12311_10  Naturally in a film who's main themes are of m...
# 1    8348_2  This movie is a disaster within a disaster fil...

# %% [markdown]
# ### process review into words

# %%
def keep_valid_words(reviews):
    wordslist = []
    for review in reviews:
        review2 = review.lower()
        words = re.findall(r'\w+', review2)        
        wordslist.append(" ".join(words).lower())
    return np.array(wordslist)

x_data = keep_valid_words(train_data['review'])
x_test = keep_valid_words(test_data['review'])
print(x_data[:2])
# Out:
# ['with all this stuff going down at the moment with mj i ve started listening to his music watching the odd documentary here and there watched the wiz and watched moonwalker again maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent moonwalker is part biography part feature film which i remember going to see at the cinema when it was originally released some of it has subtle messages about mj s feeling towards the press and also the obvious message of drugs are bad m kay br br visually impressive but of course this is all about michael jackson so unless you remotely like mj in anyway then you are going to hate this and find it boring some may call mj an egotist for consenting to the making of this movie but mj and most of his fans would say that he made it for the fans which if true is really nice of him br br the actual feature film bit when it finally starts is only on for 20 minutes or so excluding the smooth criminal sequence and joe pesci is convincing as a psychopathic all powerful drug lord why he wants mj dead so bad is beyond me because mj overheard his plans nah joe pesci s character ranted that he wanted people to know it is he who is supplying drugs etc so i dunno maybe he just hates mj s music br br lots of cool things in this like mj turning into a car and a robot and the whole speed demon sequence also the director must have had the patience of a saint when it came to filming the kiddy bad sequence as usually directors hate working with one kid let alone a whole bunch of them performing a complex dance scene br br bottom line this movie is for people who like mj on one level or another which i think is most people if not then stay away it does try and give off a wholesome message and ironically mj s bestest buddy in this movie is a girl michael jackson is truly one of the most talented people ever to grace this planet but is he guilty well with all the attention i ve gave this subject hmmm well i don t know because people can be different behind closed doors i know this for a fact he is either an extremely nice but stupid guy or one of the most sickest liars i hope he is not the latter'
#  'the classic war of the worlds by timothy hines is a very entertaining film that obviously goes to great effort and lengths to faithfully recreate h g wells classic book mr hines succeeds in doing so i and those who watched his film with me appreciated the fact that it was not the standard predictable hollywood fare that comes out every year e g the spielberg version with tom cruise that had only the slightest resemblance to the book obviously everyone looks for different things in a movie those who envision themselves as amateur critics look only to criticize everything they can others rate a movie on more important bases like being entertained which is why most people never agree with the critics we enjoyed the effort mr hines put into being faithful to h g wells classic novel and we found it to be very entertaining this made it easy to overlook what the critics perceive to be its shortcomings']

# %% [markdown]
# ### train test split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(x_data, train_data['sentiment'], test_size=0.2, random_state=0)
print(x_train.shape)
print(x_valid.shape)
# Out:
# (20000,)
# (5000,)

# %% [markdown]
# ### word count processing. TF

# %%
vectorizer = TfidfVectorizer(stop_words= 'english')
x_train_count = vectorizer.fit_transform(x_train)
x_valid_count = vectorizer.transform(x_valid)
print(vectorizer.vocabulary_)
# Out:
# {'prisons': 47004, 'exactly': 20806, 'renowned': 49931, 'kind': 33337, 'hospitality': 28896, 'happy': 27132, 'vibes': 64787, 'stories': 57710, 'fights': 22294, 'chaos': 10485, 'murder': 40410, 'course': 13791, 'extreme': 21287, 'male': 36822, 'bonding': 7489, 'prison': 47001, 'film': 22340, 'different': 16706, 'beast': 5761, 'altogether': 2563, 'horror': 28838, 'films': 22377, 'set': 53731, 'cells': 10222, 'probably': 47045, 'know': 33618, 'particularly': 44105, 'new': 41306, 'emphasis': 19682, 'exaggerate': 20809, 'fear': 21896, 'claustrophobia': 11526, 'inability': 30041, 'escape': 20417, 'greatest': 26003, 'themes': 60426, 'cinema': 11287, 'examples': 20829, 'chair': 10369, 'waldermar': 65478, 'korzeniowsky': 33747, '1988': 363, 'green': 26018, 'mile': 38861, 'frank': 23552, 'darabont': 15034, '1999': 375, 'alien': 2356, 'david': 15173, 'fincher': 22420, '1992': 368, 'entire': 20105, 'women': 66847, 'exploitation': 21131, 'genre': 24736, 'entry': 20144, 'niche': 41395, 'inventive': 31299, 'lot': 35920, 'fun': 23988, 'boot': 7615, 'order': 42886, 'recognised': 49146, 'thought': 60628, 'certainly': 10298, 'incredibly': 30246, 'enjoyable': 19956, 'ride': 50737, 'somewhat': 56090, 'shame': 53948, 'isn': 31570, 'known': 33626, 'br': 7875, 'short': 54432, 'centres': 10273, 'old': 42552, 'duh': 18561, 'reopened': 49954, 'just': 32615, 'fellow': 22024, 'inmates': 30694, 'guards': 26397, 'prisoners': 47003, 'mean': 38013, 'ass': 4102, 'demon': 15900, 'ghost': 24915, 'spirit': 56665, 'thing': 60541, 'mind': 38958, 'death': 15299, 'boy': 7853, 'treated': 61870, 'awesome': 4725, 'scenes': 52686, 'won': 66851, 'spoil': 56746, 'plenty': 45774, 'innovative': 30729, 'murders': 40419, 'invisible': 31352, 'hands': 27043, 'special': 56468, 'effects': 19142, 'going': 25469, 'cast': 9912, 'headlining': 27536, 'lord': 35879, 'rings': 50863, 'peter': 44961, 'jackson': 31729, '2001': 401, '2003': 403, 'star': 57198, 'viggo': 64905, 'mortensen': 39952, 'inclined': 30157, 'yes': 67506, 'does': 17710, 'naked': 40749, 'performance': 44735, 'highly': 28148, 'believable': 6050, 'skill': 55144, 'eastwood': 18941, 'esquire': 20497, 'character': 10517, 'bad': 4942, 'bone': 7491, 'likable': 35256, 'delicate': 15779, 'mix': 39351, 'add': 1530, 'hey': 28056, 'wait': 65450, 'minute': 39065, 'guy': 26630, 'actors': 1479, 've': 64520, 'got': 25701, 'great': 26001, 'stars': 57242, 'characters': 10535, 'lack': 34066, 'dimensionality': 16817, 'come': 12240, 'stereotypical': 57463, 'black': 6801, 'oculist': 42366, 'hard': 27161, 'nails': 40725, 'warden': 65605, 'human': 29137, 'rights': 50814, 'activist': 1473, 'woman': 66834, 'stock': 57616, 'honesty': 28651, 'fault': 21829, 'actually': 1491, 'aids': 2057, 'instead': 30866, 'boring': 7678, 'development': 16439, 'long': 35767, 'equilibrium': 20278, 'chucked': 11184, 'straight': 57769, 'action': 1452, 'gets': 24875, 'early': 18885, 'single': 54943, 'scene': 52681, 'filler': 22330, 'balls': 5149, 'wall': 65505, 'plot': 45805, 'unlike': 63539, 'certain': 10297, 'shawshank': 54083, 'redemption': 49292, '1994': 370, 'sharing': 54025, 'conventions': 13297, 'slasher': 55280, 'convention': 13293, 'good': 25564, 'ol': 42544, 'tradition': 61570, 'punishes': 47774, 'excellent': 20855, 'little': 35524, 'sadly': 51959, 'overlooked': 43367, 'unmentioned': 63583, 'world': 66994, 'original': 42959, 'recommended': 49176, 'fans': 21619, 'don': 17838, 'fooled': 23143, 'thinking': 60552, 'll': 35571, 'cheesy': 10748, 'usa': 64136, '1980s': 352, 'far': 21654, 'end': 19812, 'ruin': 51652, 'simultaneously': 54910, 'gritty': 26204, 'realistic': 48932, 'whilst': 66210, 'attempts': 4375, 'tackle': 59384, 'issues': 31597, 'rape': 48639, 'subtly': 58315, 'luvs': 36292, 'entertaining': 20081, 'nice': 41390, 'touches': 61436, 'movie': 40135, 'message': 38523, 'impressive': 29987, 'ellen': 19440, 'burstyn': 8865, 'samantha': 52141, 'mathis': 37634, 'jodelle': 32264, 'ferland': 22089, 'years': 67460, 'nominated': 41691, 'best': 6348, 'actress': 14 ...

# %% [markdown]
# ### train model

# %%
model = MultinomialNB()
model.fit(x_train_count, y_train)
y_predict = model.predict(x_valid_count)
print(y_predict.shape)
print(y_predict.dtype)
print(y_valid.shape)
print(y_valid.dtype)
accuracy_score = accuracy_score(y_valid., y_predict)
# print(accuracy_score)
# Out:
# (5000,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\miche\Career\AI_training_code\AIProject\movie_sentiment_nb.ipynb Cell 12 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/miche/Career/AI_training_code/AIProject/movie_sentiment_nb.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> y_predict = model.predict(x_valid_count)
#       <a href='vscode-notebook-cell:/c%3A/Users/miche/Career/AI_training_code/AIProject/movie_sentiment_nb.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> print(y_predict.shape)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/miche/Career/AI_training_code/AIProject/movie_sentiment_nb.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> accuracy_score = accuracy_score(y_valid, y_predict)
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# ### train model
# ### predict
# ### output
